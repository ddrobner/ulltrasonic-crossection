# %%
import matplotlib.pyplot as plt
import re

f = open("distance_test.txt", "r")
time = []
distance = []

for d in f.readlines():
    x = re.findall(r"[-+]?(?:\d*\.\d+|\d+)", d)
    distance.append(float(x[0]))
    time.append(float(x[1]))

plt.plot(time, distance)
plt.show()
